# %%
# !pip3 install firebase
# !pip3 install pyrebase
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 KB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.0/458.0 KB 18.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.8/514.8 KB 48.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 83.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.2/77.2 KB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for gcloud: filename=gcloud-0.17.0-py3-none-any.whl size=638011 sha256=e01ec14349ba20e48bb1ad543ea1ba573e470e7652fa1c1a51d63d0a8ade2253
# ...

# %%
from pprint import pprint

# %%
import firebase
import pyrebase

config ={
   "apiKey": "AIzaSyDojdR-Tv9NonyHX_NgauL7p884pxrUwhc",
  "authDomain": "project-4c6a5.firebaseapp.com",
  "projectId": "project-4c6a5",
  "databaseURL":"https://project-4c6a5-default-rtdb.asia-southeast1.firebasedatabase.app/",
  "storageBucket": "project-4c6a5.appspot.com",
  "messagingSenderId": "463469946308",
  "appId": "1:463469946308:web:852b9af702a4a4c02c3091",
  "measurementId": "G-2JNB4HFW9D"
}

firebase =pyrebase.initialize_app(config)
database =firebase.database()

data = {"Product":"ball","Quantity Ordered":47,"Price":600,"date":"23/03/2024"}


# database.push(data)
# print(data)
# first=database.child("-NQH0hNmVYUgrdpy_bH1").get()
 
database.child("trend").child("15").set(data)
first=database.child("trend").get()
pprint(first.val())
# Out:
# OrderedDict([('1',
#               {'Price': 700,
#                'Product': 'T-shirt',
#                'Quantity Ordered': 13,
#                'date': '18/03/2024'}),
#              ('2',
#               {'Price': 700,
#                'Product': 'T-shirt',
#                'Quantity Ordered': 17,
#                'date': '19/03/2024'}),
#              ('3',
#               {'Price': 700,
#                'Product': 'T-shirt',
#                'Quantity Ordered': 23,
#                'date': '20/03/2024'}),
#              ('4',
#               {'Price': 700,
#                'Product': 'T-shirt',
#                'Quantity Ordered': 21,
#                'date': '21/03/2024'}),
#              ('5',
#               {'Price': 700,
#                'Product': 'T-shirt',
#                'Quantity Ordered': 29,
#                'date': '22/03/2024'}),
#              ('6',
#               {'Price': 700,
#                'Product': 'T-shirt',
#                'Quantity Ordered': 36,
# ...

# %%
import numpy as np
import json as json
from collections import OrderedDict

# print(type(first.val()))
od=first.val()
pprint(type(od))


#_______________________________
# od = json.dumps(od)
  
od = json.dumps(od, indent=2)
# check type i.e; str

#_______________________________
print(type(od))
# pprint(od)


#_______________________________converts json to dict
con= json.loads(od)
print(type(con))

#_______________________________converts dict to numpy
result = con.items()
 
# # Convert object to a list
dt = list(result)
 
# # Convert list to an array
numpyArray = np.array(dt)
 
# # print the numpy array
print(numpyArray)
print(type(numpyArray))
# Out:
# <class 'collections.OrderedDict'>
# <class 'str'>
# <class 'dict'>
# [['1'
#   {'Price': 700, 'Product': 'T-shirt', 'Quantity Ordered': 13, 'date': '18/03/2024'}]
#  ['2'
#   {'Price': 700, 'Product': 'T-shirt', 'Quantity Ordered': 17, 'date': '19/03/2024'}]
#  ['3'
#   {'Price': 700, 'Product': 'T-shirt', 'Quantity Ordered': 23, 'date': '20/03/2024'}]
#  ['4'
#   {'Price': 700, 'Product': 'T-shirt', 'Quantity Ordered': 21, 'date': '21/03/2024'}]
#  ['5'
#   {'Price': 700, 'Product': 'T-shirt', 'Quantity Ordered': 29, 'date': '22/03/2024'}]
#  ['6'
#   {'Price': 700, 'Product': 'T-shirt', 'Quantity Ordered': 36, 'date': '23/03/2024'}]
#  ['7'
#   {'Price': 700, 'Product': 'T-shirt', 'Quantity Ordered': 41, 'date': '24/03/2024'}]
#  ['8'
#   {'Price': 700, 'Product': 'T-shirt', 'Quantity Ordered': 33, 'date': '25/03/2024'}]
#  ['9'
#   {'Price': 700, 'Product': 'T-shirt', 'Quantity Ordered': 37, 'date': '26/03/2024'}]
#  ['10'
# ...

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
from plotly.offline import iplot

# %%
import matplotlib.pyplot as plt


dt = pd.DataFrame(con)
dt.head()
# Out:
#                            1           2           3           4           5  \
# Price                    700         700         700         700         700
# Product              T-shirt     T-shirt     T-shirt     T-shirt     T-shirt
# Quantity Ordered          13          17          23          21          29
# date              18/03/2024  19/03/2024  20/03/2024  21/03/2024  22/03/2024
#
#                            6           7           8           9          10  \
# Price                    700         700         700         700         600
# Product              T-shirt     T-shirt     T-shirt     T-shirt        ball
# Quantity Ordered          36          41          33          37          11
# date              23/03/2024  24/03/2024  25/03/2024  26/03/2024  18/03/2024
#
#                           11          12          13          14          15  \
# Price                    600         600         600         600         600
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle as pl

od=first.val()
  
od = json.dumps(od, indent=2)

con= json.loads(od)

result = con.items()
 
numpyArray = np.array(result)

# dt = pd.DataFrame(con)
# # print(dt.head())

# dt = dt.T

# # dt_np = dt.values
# # dt_np=pd.DataFrame(dt_np)

# df = pd.DataFrame(dt, columns = ["Product","Quantity Ordered","Price","date"])
# df



dt = pd.DataFrame(con)
dt = dt.T
df = pd.DataFrame(dt, columns = ["Product","Quantity Ordered","Price","date"])
df
# Out:
#        Product Quantity Ordered Price        date
# 1      T-shirt               13   700  18/03/2024
# 2      T-shirt               17   700  19/03/2024
# 3      T-shirt               23   700  20/03/2024
# 4      T-shirt               21   700  21/03/2024
# 5      T-shirt               29   700  22/03/2024
# 6      T-shirt               36   700  23/03/2024
# 7      T-shirt               41   700  24/03/2024
# 8      T-shirt               33   700  25/03/2024
# 9      T-shirt               37   700  26/03/2024
# 10        ball               11   600  18/03/2024
# 11        ball               19   600  19/03/2024
# 12        ball               27   600  20/03/2024
# 13        ball               33   600  21/03/2024
# 14        ball               32   600  22/03/2024
# 15        ball               47   600  23/03/2024
# first  T-shirt               19   700  19/03/2024

# %%
from datetime import datetime,date


result = []
for x in df["date"]:
    day_of_year = date(int(x.split('/')[2]),int(x.split('/')[1]),int(x.split('/')[0])).timetuple().tm_yday
    result.append(day_of_year)

df["Day of year"] = result  
print(df)
# df[['date']]
# day_of_year



#*********************************************************************************************************
# def day(x):
  
#   day_of_year = date(int(x.split('/')[2]),int(x.split('/')[1]),int(x.split('/')[0])).timetuple().tm_yday
#   # print(day_of_year)
#   # x.split('/')[0]
#   # x.split('/')[1]
#   # x.split('/')[2]
#   return day_of_year
# df['date'] = pd.to_datetime(df['date'], dayfirst=True)
# Out:
#        Product Quantity Ordered Price        date  Day of year
# 1      T-shirt               13   700  18/03/2024           78
# 2      T-shirt               17   700  19/03/2024           79
# 3      T-shirt               23   700  20/03/2024           80
# 4      T-shirt               21   700  21/03/2024           81
# 5      T-shirt               29   700  22/03/2024           82
# 6      T-shirt               36   700  23/03/2024           83
# 7      T-shirt               41   700  24/03/2024           84
# 8      T-shirt               33   700  25/03/2024           85
# 9      T-shirt               37   700  26/03/2024           86
# 10        ball               11   600  18/03/2024           78
# 11        ball               19   600  19/03/2024           79
# 12        ball               27   600  20/03/2024           80
# 13        ball               33   600  21/03/2024           81
# 14        ball               32   600  22/03/2024           82
# ...

# %%
df.shape
# Out:
# (16, 5)

# %%
plt.figure(figsize=(16,8))
plt.title('Trend')
plt.plot(df["Quantity Ordered"])
plt.xlabel('date')
plt.ylabel('total stock ordered')
plt.show()

# %%
df.plot(x="date", y=["Quantity Ordered"],
        kind="line", figsize=(10, 10))
 
# display plot
plt.show()

# %%
# plt.figure(figsize=(16,8))
# plt.title('Trend')
# plt.plot(df["Quantity Ordered"])
# plt.xlabel('Day of year')
# plt.ylabel('total stock ordered')
# plt.show()
df.plot(x="Day of year", y=["Quantity Ordered"],
        kind="line", figsize=(10, 10))
 
# display plot
plt.show()

# %%
# Group Rows on 'Courses' column and get List for 'Fee' column
df2 = df.groupby(['Product','Quantity Ordered'])['date']
print(df2.head())
# df2.head()
# grouped = df.groupby(['Region', 'Type'])['Units'].sum()
# print(grouped.head())
# Out:
# 1       2024-03-18
# 2       2024-03-19
# 3       2024-03-20
# 4       2024-03-21
# 5       2024-03-22
# 6       2024-03-23
# 7       2024-03-24
# 8       2024-03-25
# 9       2024-03-26
# 10      2024-03-18
# 11      2024-03-19
# 12      2024-03-20
# 13      2024-03-21
# 14      2024-03-22
# 15      2024-03-23
# first   2024-03-19
# Name: date, dtype: datetime64[ns]

# %%
df2 = df.groupby("Product").agg(list)
print(df2)
# Out:
#                                  Quantity Ordered  \
# Product
# T-shirt  [13, 17, 23, 21, 29, 36, 41, 33, 37, 19]
# ball                     [11, 19, 27, 33, 32, 47]
#
#                                                      Price  \
# Product
# T-shirt  [700, 700, 700, 700, 700, 700, 700, 700, 700, ...
# ball                        [600, 600, 600, 600, 600, 600]
#
#                                                       date
# Product
# T-shirt  [18/03/2024, 19/03/2024, 20/03/2024, 21/03/202...
# ball     [18/03/2024, 19/03/2024, 20/03/2024, 21/03/202...

# %%
df.set_index('date', inplace=True)
df.groupby('Product')['Quantity Ordered'].plot(legend=True)
# Out:
# Product
# T-shirt    Axes(0.125,0.125;0.775x0.755)
# ball       Axes(0.125,0.125;0.775x0.755)
# Name: Quantity Ordered, dtype: object

# %%
from datetime import datetime,date
def day(x):
  
  day_of_year = date(int(x.split('/')[2]),int(x.split('/')[1]),int(x.split('/')[0])).timetuple().tm_yday
  # print(day_of_year)
  # x.split('/')[0]
  # x.split('/')[1]
  # x.split('/')[2]
  return day_of_year
# dt['Day']=dt['date'].apply(date)   # date
# dt['dayofyear'] = dt['date'].dt.dayofyear
print(type(dt['date']))
df.dtypes
# Out:
# <class 'pandas.core.series.Series'>
# Product             object
# Quantity Ordered    object
# Price               object
# Day of year          int64
# dtype: object

# %%
def daycl(x):
  result = []
  for value in x:
      day_of_year = date(int(x.split('/')[2]),int(x.split('/')[1]),int(x.split('/')[0])).timetuple().tm_yday
  return result
# df = pd.DataFrame({'date': ['4/03/2022', '5/03/2022', '6/03/2022'],
#                    'patients': [16, 19, 11]})
 
# df['date'] = pd.to_datetime(df['date'], dayfirst=True)
df
# Out:
#             Product Quantity Ordered Price  Day of year
# date
# 18/03/2024  T-shirt               13   700           78
# 19/03/2024  T-shirt               17   700           79
# 20/03/2024  T-shirt               23   700           80
# 21/03/2024  T-shirt               21   700           81
# 22/03/2024  T-shirt               29   700           82
# 23/03/2024  T-shirt               36   700           83
# 24/03/2024  T-shirt               41   700           84
# 25/03/2024  T-shirt               33   700           85
# 26/03/2024  T-shirt               37   700           86
# 18/03/2024     ball               11   600           78
# 19/03/2024     ball               19   600           79
# 20/03/2024     ball               27   600           80
# 21/03/2024     ball               33   600           81
# 22/03/2024     ball               32   600           82
# 23/03/2024     ball               47   600           83
# 19/03/2024  T-shirt               19   700           79

# %%
def date(x):
    return x.split('/')[1]
dt=df

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error

quant=dt[['Quantity Ordered']]
date=dt[['Day of year']]


dt_x_train=quant[:-5]
dt_x_test=quant[-5:]

dt_y_train=date[:-5]
dt_y_test=date[-5:]

model=linear_model.LinearRegression()

model.fit(dt_x_train ,dt_y_train)
dt_y_predicted=model.predict(dt_x_test)

print(dt_y_predicted)
# Out:
# [[81.76094796]
#  [83.30345183]
#  [83.04636785]
#  [86.90262751]
#  [79.70427615]]

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error

quant=dt[['Quantity Ordered']]
date=dt[['Day of year']]


dt_x_train=quant[-7:]
dt_x_test=quant[:-7]

dt_y_train=date[-7:]
dt_y_test=date[:-7]

model=linear_model.LinearRegression()

model.fit(dt_y_train ,dt_x_train)
dt_y_predicted=model.predict(dt_y_test)

print(dt_y_predicted)
# print("mean squared error: ",mean_squared_error(diabetes_y_test,diabetes_y_predicted))
# Out:
# [[12.23529412]
#  [18.63235294]
#  [25.02941176]
#  [31.42647059]
#  [37.82352941]
#  [44.22058824]
#  [50.61764706]
#  [57.01470588]
#  [63.41176471]]

# %%
from sklearn.metrics import r2_score
score = r2_score(dt_x_test, dt_y_predicted)
print("The accuracy of our model is {}%".format(round(score, 2) *100))
# Out:
# The accuracy of our model is -113.99999999999999%
