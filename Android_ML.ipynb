# %%
# !pip3 install firebase
# !pip3 install pyrebase

# %%
from pprint import pprint

# %%
import firebase
import pyrebase

config ={
   "apiKey": "AIzaSyDKHCT0eF3FOIgCFVyH6oxSyHU2F7xVrFs",#
  "authDomain": "visualizegrow.firebaseapp.com",#
  "projectId": "visualizegrow",#
  "databaseURL":"https://visualizegrow-default-rtdb.firebaseio.com/",#
  "storageBucket": "visualizegrow.appspot.com",#
  # "messagingSenderId": "463469946308",
  "appId": "1:587676540367:android:c55af51e20426c900346ba",#
  # "measurementId": "G-2JNB4HFW9D"
}

firebase =pyrebase.initialize_app(config)
database =firebase.database()

data = {"Product":"Carrybag","Quantity Ordered":1000,"Price":50,"date":"27/03/2024"}


# database.push(data)
# print(data)
# first=database.child("-NQH0hNmVYUgrdpy_bH1").get()
 
# database.child("products").child("15").set(data)
first=database.child("products").get()
pprint(first.val())
# Out:
# OrderedDict([('1',
#               {'Price': 100,
#                'Product': 'pens',
#                'Quantity Ordered': 810,
#                'date': '8/03/2024'}),
#              ('2',
#               {'Price': 700,
#                'Product': 'balls',
#                'Quantity Ordered': 810,
#                'date': '19/03/2024'}),
#              ('3',
#               {'Price': 100,
#                'Product': 'keyboard',
#                'Quantity Ordered': 110,
#                'date': '28/03/2024'}),
#              ('4',
#               {'Price': 100,
#                'Product': 'Carrybag',
#                'Quantity Ordered': 118,
#                'date': '21/03/2024'}),
#              ('5',
#               {'Price': 78,
#                'Product': 'Bucket',
#                'Quantity Ordered': 19,
#                'date': '17/03/2024'}),
#              ('6',
#               {'Price': 7000,
#                'Product': 'Washing machine',
# ...

# %%
import numpy as np
import json as json
from collections import OrderedDict

# print(type(first.val()))
od=first.val()
pprint(type(od))


#_______________________________
# od = json.dumps(od)
  
od = json.dumps(od, indent=2)
# check type i.e; str

#_______________________________
print(type(od))
# pprint(od)


#_______________________________converts json to dict
con= json.loads(od)
print(type(con))

#_______________________________converts dict to numpy
result = con.items()
 
# # Convert object to a list
dt = list(result)
 
# # Convert list to an array
numpyArray = np.array(dt)
 
# # print the numpy array
print(numpyArray)
print(type(numpyArray))
# Out:
# <class 'collections.OrderedDict'>
# <class 'str'>
# <class 'dict'>
# [['1'
#   {'Price': 100, 'Product': 'pens', 'Quantity Ordered': 810, 'date': '8/03/2024'}]
#  ['2'
#   {'Price': 700, 'Product': 'balls', 'Quantity Ordered': 810, 'date': '19/03/2024'}]
#  ['3'
#   {'Price': 100, 'Product': 'keyboard', 'Quantity Ordered': 110, 'date': '28/03/2024'}]
#  ['4'
#   {'Price': 100, 'Product': 'Carrybag', 'Quantity Ordered': 118, 'date': '21/03/2024'}]
#  ['5'
#   {'Price': 78, 'Product': 'Bucket', 'Quantity Ordered': 19, 'date': '17/03/2024'}]
#  ['6'
#   {'Price': 7000, 'Product': 'Washing machine', 'Quantity Ordered': 50, 'date': '07/03/2024'}]
#  ['7'
#   {'Price': 700, 'Product': 'Bat', 'Quantity Ordered': 50, 'date': '27/03/2024'}]
#  ['8'
#   {'Price': 700, 'Product': 'Bat', 'Quantity Ordered': 57, 'date': '26/03/2024'}]
#  ['9'
#   {'Price': 9000, 'Product': 'laptop', 'Quantity Ordered': 570, 'date': '13/03/2024'}]
#  ['10'
# ...

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
from plotly.offline import iplot

# %%
import matplotlib.pyplot as plt


dt = pd.DataFrame(con)
dt.head()
# Out:
#                           1           2           3           4           5  \
# Price                   100         700         100         100          78
# Product                pens       balls    keyboard    Carrybag      Bucket
# Quantity Ordered        810         810         110         118          19
# date              8/03/2024  19/03/2024  28/03/2024  21/03/2024  17/03/2024
#
#                                 6           7           8           9  \
# Price                        7000         700         700        9000
# Product           Washing machine         Bat         Bat      laptop
# Quantity Ordered               50          50          57         570
# date                   07/03/2024  27/03/2024  26/03/2024  13/03/2024
#
#                           10          11          12          13          14  \
# Price                     90          90          90          50          50
# Product                 Soap        Soap        Soap       balls       balls
# ...

# %%
od=first.val()
  
od = json.dumps(od, indent=2)

con= json.loads(od)

result = con.items()
 
numpyArray = np.array(result)

dt = pd.DataFrame(con)

dt = dt.T
data = dt.groupby(["Product"], as_index=False)['Quantity Ordered'].sum()

dt_np = data.values

names = dt_np[:,0]
values = dt_np[:,1]

# %% [markdown]
# ### Monthly Product Sell

# %%
plt.figure(figsize=(15,6))
plt.bar(names, values)
plt.ylabel("Qualtity")
# for i in dt_np:
#     print(i[0],i[1])
#     plt.text(i[0], i[1], s=i[1])

plt.xlabel("Products")
plt.title("Monthly Sales Report")
plt.show()

# %% [markdown]
# Monthly Product Sell

# %% [markdown]
# ### **                               Monthly Product                **
#
# ---
#
#
#
# ---

# %%
od=first.val()
  
od = json.dumps(od, indent=2)

con= json.loads(od)

result = con.items()
 
numpyArray = np.array(result)

dt = pd.DataFrame(con)
print(dt.head())

dt = dt.T

dt_np = dt.values

data = dt.groupby(["date","Product"], as_index=False)['Quantity Ordered'].sum()

curr_date = '27/03/2024'
data = data[data['date']==curr_date]

np_data = data.values

# from datetime import datetime
# now = datetime.now()
# curr_date = now.strftime("%d/%m/%Y")
plt.bar(np_data[:,1], np_data[:,2])
plt.ylabel("Qualtity")
plt.xlabel("Product")

for i in np_data:
    print(i[1],i[2])
    plt.text(i[1], i[2], s=i[2])

plt.title(f"Daily Sales Report for {curr_date}")
plt.show()
# Out:
#                           1           2           3           4           5  \
# Price                   100         700         100         100          78
# Product                pens       balls    keyboard    Carrybag      Bucket
# Quantity Ordered        810         810         110         118          19
# date              8/03/2024  19/03/2024  28/03/2024  21/03/2024  17/03/2024
#
#                                 6           7           8           9  \
# Price                        7000         700         700        9000
# Product           Washing machine         Bat         Bat      laptop
# Quantity Ordered               50          50          57         570
# date                   07/03/2024  27/03/2024  26/03/2024  13/03/2024
#
#                           10          11          12          13          14  \
# Price                     90          90          90          50          50
# Product                 Soap        Soap        Soap       balls       balls
# ...

# %% [markdown]
# Daily sales report

# %% [markdown]
# ### Daily sales report

# %%
import numpy as np
